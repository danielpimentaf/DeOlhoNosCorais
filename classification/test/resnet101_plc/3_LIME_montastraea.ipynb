# %% [markdown]
# # Carregando Pacotes

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from pathlib import Path
import os
from matplotlib import pyplot as plt
import lime
from lime import lime_image
from skimage.segmentation import mark_boundaries
# Out:
# 2022-06-19 21:06:41.821496: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# # Parâmetros

# %%
# Tamanho imagem
img_rows, img_cols = 224, 224

input_shape = (img_rows, img_cols, 3)

# Batch size

batch_size = 32

# seed
seed = 42

path_dataset = Path('/scratch/dpfurtado/backup_home/corais/1_classificacao_train_50/dataset/1_train_50')
path_train = path_dataset/'train'
path_train_dev = path_dataset/'test_1_2'

options = tf.data.Options()
options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.DATA

# %% [markdown]
# # Carregando Base de Dados

# %%
train_dataset = image_dataset_from_directory(
        path_train,
        image_size=(img_rows, img_cols),
        color_mode="rgb",
        batch_size=batch_size,
        shuffle=False) # Manter Shuffle = False, pois não haverá treinamento
test_dataset = image_dataset_from_directory(
        path_train_dev,
        image_size=(img_rows, img_cols),
        color_mode="rgb",
        batch_size=batch_size,
        shuffle=False)
# Out:
# Found 788 files belonging to 7 classes.
# Found 168 files belonging to 7 classes.
# 2022-06-19 21:06:45.040247: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-19 21:06:45.042327: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-06-19 21:06:45.924204: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce GTX TITAN Black computeCapability: 3.5
# coreClock: 0.98GHz coreCount: 15 deviceMemorySize: 5.94GiB deviceMemoryBandwidth: 312.92GiB/s
# 2022-06-19 21:06:45.924857: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:af:00.0 name: NVIDIA GeForce GTX TITAN Black computeCapability: 3.5
# coreClock: 0.98GHz coreCount: 15 deviceMemorySize: 5.94GiB deviceMemoryBandwidth: 312.92GiB/s
# 2022-06-19 21:06:45.924888: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-19 21:06:45.929890: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-06-19 21:06:45.929993: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-06-19 21:06:45.933297: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-06-19 21:06:45.933825: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-06-19 21:06:45.937218: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-06-19 21:06:45.938301: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-06-19 21:06:45.945069: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-06-19 21:06:45.947131: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2022-06-19 21:06:45.948756: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-19 21:06:46.044457: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:3b:00.0 name: NVIDIA GeForce GTX TITAN Black computeCapability: 3.5
# coreClock: 0.98GHz coreCount: 15 deviceMemorySize: 5.94GiB deviceMemoryBandwidth: 312.92GiB/s
# 2022-06-19 21:06:46.045138: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:af:00.0 name: NVIDIA GeForce GTX TITAN Black computeCapability: 3.5
# coreClock: 0.98GHz coreCount: 15 deviceMemorySize: 5.94GiB deviceMemoryBandwidth: 312.92GiB/s
# 2022-06-19 21:06:46.045230: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-19 21:06:46.045292: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-06-19 21:06:46.045310: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-06-19 21:06:46.045329: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-06-19 21:06:46.045346: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-06-19 21:06:46.045364: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-06-19 21:06:46.045383: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-06-19 21:06:46.045397: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-06-19 21:06:46.047033: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2022-06-19 21:06:46.047103: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-19 21:06:47.045824: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-06-19 21:06:47.045961: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1
# 2022-06-19 21:06:47.045971: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N Y
# 2022-06-19 21:06:47.045976: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   Y N
# 2022-06-19 21:06:47.048857: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 5581 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX TITAN Black, pci bus id: 0000:3b:00.0, compute capability: 3.5)
# 2022-06-19 21:06:47.051084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 5581 MB memory) -> physical GPU (device: 1, name: NVIDIA GeForce GTX TITAN Black, pci bus id: 0000:af:00.0, compute capability: 3.5)
# 2022-06-19 21:06:47.051483: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %%
# Index para classe 
classes = train_dataset.class_names #Essa função e .file_paths não podem ser usados após o prefetch
classes_dict = dict(enumerate(classes)) 
print(classes_dict)
# Out:
# {0: 'agaricia_spp', 1: 'favia_gravida', 2: 'millepora_alcicornis', 3: 'montastraea_cavernosa', 4: 'palythoa_caribaeorum', 5: 'porites_astreoides', 6: 'siderastrea_stellata'}

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.cache().prefetch(buffer_size=AUTOTUNE) #Otimização
test_dataset = test_dataset.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Carregando Modelo

# %%
path_modelo = './model/resnet_plc_full_transfer/'

# %%
best_model = tf.keras.models.load_model(path_modelo)

# %%
best_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# model (Functional)           (None, 2048)              42658176
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 14343
# =================================================================
# Total params: 42,672,519
# Trainable params: 42,567,175
# Non-trainable params: 105,344
# _________________________________________________________________

# %% [markdown]
# # Analisando Classe 3

# %%
class_index = 3
print(classes_dict[class_index])
# Out:
# montastraea_cavernosa

# %%
path_dir_red_fox =  path_train_dev/'montastraea_cavernosa/'

# %%
red_fox_dataset = test_dataset.unbatch().filter(lambda x, y: y == class_index).batch(batch_size)

# %%
predict_red_fox=best_model.predict(red_fox_dataset)
predict_red_fox_classes = np.argmax(predict_red_fox, axis=1)
# Out:
# 2022-06-19 21:07:12.392229: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-06-19 21:07:12.412883: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2200000000 Hz
# 2022-06-19 21:07:14.380599: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-06-19 21:07:15.563150: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7

# %%
list_index_red_fox = np.where(predict_red_fox_classes != class_index)

# %%
print(list_index_red_fox[0])
# Out:
# [ 2  3  4  5  7  8 10 14 15 16 17 18 19 20 22 24 25 28 30 31 32]

# %%
path_imgs = os.listdir(path_dir_red_fox)
path_imgs.sort()

# %%
for img_incorrect in list_index_red_fox[0]:
  print(path_imgs[img_incorrect])
# Out:
# 2019-10-23_14-12-02_UTC_6.jpg
# 2019-10-23_14-12-02_UTC_7.jpg
# 2019-10-23_18-50-59_UTC.jpg
# 2019-10-27_22-04-27_UTC_3.jpg
# 2019-12-11_11-11-27_UTC_1.jpg
# 2019-12-11_11-11-27_UTC_2.jpg
# 2019-12-21_13-14-42_UTC_2 (1).jpg
# 2019-12-28_19-51-05_UTC_6.jpg
# 2020-01-13_23-42-03_UTC.jpg
# 2020-01-14_22-48-10_UTC_1.jpg
# 2020-01-14_22-48-10_UTC_3.jpg
# 2020-01-14_22-48-10_UTC_4.jpg
# 2020-01-16_10-40-17_UTC.jpg
# 2020-01-22_11-43-09_UTC.jpg
# 2020-02-11_17-47-07_UTC.jpg
# 2020-02-17_11-37-05_UTC.jpg
# 2020-03-11_23-34-25_UTC_1.jpg
# 2020-03-15_02-19-01_UTC (1).jpg
# 2020-06-16_11-53-38_UTC.jpg
# 2020-06-20_20-12-23_UTC_1.jpg
# 2020-06-20_20-12-23_UTC_3.jpg

# %% [markdown]
# # LIME

# %%
# Descobrindo o index da image
index_correta = path_imgs.index('2019-10-27_22-04-27_UTC_3.jpg')
print(index_correta)
# Out:
# 5

# %%
imagem_correta, label_imagem_correta = list(red_fox_dataset.unbatch().as_numpy_iterator())[index_correta]

# %%
def decode(softmax):
    prob = []
    for key, value in classes_dict.items():
        prob_classe = softmax[key]
        prob.append((value, prob_classe))
    prob.sort(key=lambda x:x[1], reverse=True)
    return prob

# %%
plt.imshow(imagem_correta/255)
preds = best_model.predict(np.expand_dims(imagem_correta, axis=0)) #Predição de uma única imagem
soft_preds=tf.nn.softmax(preds).numpy().flatten()
decode_prof=decode(soft_preds)
for list_prob in decode_prof[:3]:
    print('Classe: {} - Probabilidade: {:.6f}'.format(list_prob[0], list_prob[1]))
# Out:
# Classe: siderastrea_stellata - Probabilidade: 0.997019
# Classe: montastraea_cavernosa - Probabilidade: 0.002499
# Classe: palythoa_caribaeorum - Probabilidade: 0.000406

# %%
explainer_correta = lime_image.LimeImageExplainer()

# %%
# %%time
explanation_correta = explainer_correta.explain_instance(imagem_correta.astype('double'), best_model.predict, top_labels=3, hide_color=0, num_samples=1000)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# CPU times: user 20.2 s, sys: 3.42 s, total: 23.6 s
# Wall time: 21.8 s

# %% [markdown]
# ### Para a Classe mais provável

# %%
temp, mask = explanation_correta.get_image_and_mask(explanation_correta.top_labels[0], positive_only=True, num_features=20, hide_rest=True)
img=plt.imshow(mark_boundaries(temp /255, mask))
plt.axis('off')
plt.show();

# %%
temp, mask = explanation_correta.get_image_and_mask(explanation_correta.top_labels[0], positive_only=True, num_features=20, hide_rest=False)
img=plt.imshow(mark_boundaries(temp /255, mask))
plt.axis('off')
plt.show();

# %%
temp, mask = explanation_correta.get_image_and_mask(explanation_correta.top_labels[0], positive_only=False, num_features=20, hide_rest=False)
img=plt.imshow(mark_boundaries(temp /255, mask))
plt.axis('off')
plt.show();

# %%
#Selecionar a classe mais provável
ind =  explanation_correta.top_labels[0]

#Mapeamento os pesos para cada explicação
dict_heatmap = dict(explanation_correta.local_exp[ind])
heatmap = np.vectorize(dict_heatmap.get)(explanation_correta.segments) 

#Plot
img=plt.imshow(heatmap, cmap = 'RdBu', vmin  = -heatmap.max(), vmax = heatmap.max())
plt.colorbar()
plt.axis('off')
plt.show();

# %% [markdown]
# ### Para segunda classe mais provavel

# %%
temp, mask = explanation_correta.get_image_and_mask(explanation_correta.top_labels[1], positive_only=True, num_features=20, hide_rest=True)
img=plt.imshow(mark_boundaries(temp /255, mask))
plt.axis('off')
plt.show();

# %%
temp, mask = explanation_correta.get_image_and_mask(explanation_correta.top_labels[1], positive_only=False, num_features=20, hide_rest=False)
img=plt.imshow(mark_boundaries(temp /255, mask))
plt.axis('off')
plt.show();

# %%
#Selecionar a classe mais provável
ind =  explanation_correta.top_labels[1]

#Mapeamento os pesos para cada explicação
dict_heatmap = dict(explanation_correta.local_exp[ind])
heatmap = np.vectorize(dict_heatmap.get)(explanation_correta.segments) 

#Plot
img=plt.imshow(heatmap, cmap = 'RdBu', vmin  = -heatmap.max(), vmax = heatmap.max())
plt.colorbar()
plt.axis('off')
plt.show();
